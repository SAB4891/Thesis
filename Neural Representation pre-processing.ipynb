# %% [markdown]
# ## Neural Representation pre-processing

# %%
import os 
os.chdir('C:\\Users\\User\\Desktop\\reps')

# %%
import pandas as pd 
data = pd.read_csv("info.csv") # <----- data file that will dictates the order of mp3s (their phonemes and features) in reps. 

origs = ['pizza','person','table','tennis','dog', 'cake', 'game', 'girl', 'kite', 'bench', 'boat', 'day']
manips =['beetza','berson', 'dable', 'dennis', 'tog', 'gayk', 'kame', 'kirl', 'guyte', 'pench', 'poat', 'tay']

manipulated_mp3 =[]
MP3=[]
for element in data['path']:
    MP3.append(element)
    
original_mp3 = MP3.copy()
    

for element in MP3:
    x =element.split('_')[0].split('.')[0]
    if x in manips:
        original_mp3.remove(element)
        manipulated_mp3.append(element)
        
print(manipulated_mp3)
# Out:
# ['beetza_1.mp3', 'beetza_161925.mp3', 'beetza_2.mp3', 'beetza_385029.mp3', 'berson__35197.mp3', 'berson__460841.mp3', 'berson__534601.mp3', 'berson__8021.mp3', 'dable__142620.mp3', 'dable__329455.mp3', 'dable__405691.mp3', 'dable__87742.mp3', 'dennis__117744.mp3', 'dennis__379332.mp3', 'dennis__404922.mp3', 'dennis__515828.mp3', 'gayk.mp3', 'gayk__155179.mp3', 'gayk__334483.mp3', 'gayk__405249.mp3', 'guyte__124442.mp3', 'guyte__289960.mp3', 'guyte__478721.mp3', 'guyte__511647.mp3', 'guyte__7511.mp3', 'kame.mp3', 'kame__12639.mp3', 'kame__237071.mp3', 'kame__302107.mp3', 'kirl_1.mp3', 'kirl_2.mp3', 'kirl__445999.mp3', 'kirl__546475.mp3', 'pench__227478.mp3', 'pench__349184.mp3', 'pench__464251.mp3', 'pench__89697.mp3', 'poat.mp3', 'poat__116439.mp3', 'poat__160728.mp3', 'poat__570448.mp3', 'tay_1.mp3', 'tay_2.mp3', 'tay__179392.mp3', 'tay__312237.mp3', 'tog_1.mp3', 'tog_2.mp3', 'tog__140203.mp3', 'tog__82807.mp3']

# %%
#import the audio alignment file generated by the Gentle toolkit 
# and create a dictionary with embedded dictionary for each MP3 

import json
with open('fa.json') as X:
    fa= json.load(X)
fa

# %%
FA = dict((utt['path'], utt) for utt in fa)

FA

# %%
# count the phonemes for each MP3 name and compile them in dicionaries 
# and manually adjust the one of malformed mp3 (GTTS malfunction)

PHO_manips={}
for mp3 in manipulated_mp3:
    total = 0
    for word in FA[mp3]['words']:
        phoneme_count = len(word['phones'])
        total=total+phoneme_count
    PHO_manips[mp3]=total
    
PHO_manips['gayk__155179.mp3']=26
PHO_manips['kame.mp3']=18
PHO_manips['kame__12639.mp3']=19
PHO_manips['kirl_1.mp3']=19
PHO_manips['kirl__546475.mp3']= 23

print(PHO_manips)
# Out:
# {'beetza_1.mp3': 30, 'beetza_161925.mp3': 30, 'beetza_2.mp3': 27, 'beetza_385029.mp3': 27, 'berson__35197.mp3': 36, 'berson__460841.mp3': 28, 'berson__534601.mp3': 27, 'berson__8021.mp3': 29, 'dable__142620.mp3': 25, 'dable__329455.mp3': 27, 'dable__405691.mp3': 25, 'dable__87742.mp3': 28, 'dennis__117744.mp3': 26, 'dennis__379332.mp3': 28, 'dennis__404922.mp3': 41, 'dennis__515828.mp3': 27, 'gayk.mp3': 24, 'gayk__155179.mp3': 26, 'gayk__334483.mp3': 31, 'gayk__405249.mp3': 38, 'guyte__124442.mp3': 21, 'guyte__289960.mp3': 22, 'guyte__478721.mp3': 25, 'guyte__511647.mp3': 30, 'guyte__7511.mp3': 22, 'kame.mp3': 18, 'kame__12639.mp3': 19, 'kame__237071.mp3': 26, 'kame__302107.mp3': 32, 'kirl_1.mp3': 19, 'kirl_2.mp3': 28, 'kirl__445999.mp3': 31, 'kirl__546475.mp3': 23, 'pench__227478.mp3': 26, 'pench__349184.mp3': 28, 'pench__464251.mp3': 28, 'pench__89697.mp3': 25, 'poat.mp3': 23, 'poat__116439.mp3': 25, 'poat__160728.mp3': 26, 'poat__570448.mp3': 23, 'tay_1.mp3': 22, 'tay_2.mp3': 21, 'tay__179392.mp3': 29, 'tay__312237.mp3': 30, 'tog_1.mp3': 19, 'tog_2.mp3': 27, 'tog__140203.mp3': 27, 'tog__82807.mp3': 29}

# %%
PHO_org={}
for mp3 in original_mp3:
    total = 0
    for word in FA[mp3]['words']:
        phoneme_count = len(word['phones'])
        total=total+phoneme_count
    PHO_org[mp3]=total
    PHO_org['cake__155179.mp3']=26
    PHO_org['game.mp3']=18
    PHO_org['game__12639.mp3']=19
    PHO_org['girl_1.mp3']=19
    PHO_org['girl__546475.mp3']= 23

print(PHO_org)
# Out:
# {'bench__227478.mp3': 26, 'cake__155179.mp3': 26, 'game.mp3': 18, 'game__12639.mp3': 19, 'girl_1.mp3': 19, 'girl__546475.mp3': 23, 'bench__349184.mp3': 28, 'bench__464251.mp3': 28, 'bench__89697.mp3': 25, 'boat.mp3': 23, 'boat__116439.mp3': 25, 'boat__160728.mp3': 26, 'boat__570448.mp3': 23, 'cake.mp3': 24, 'cake__334483.mp3': 31, 'cake__405249.mp3': 38, 'day_1.mp3': 22, 'day_2.mp3': 21, 'day__179392.mp3': 29, 'day__312237.mp3': 30, 'dog_1.mp3': 19, 'dog_2.mp3': 27, 'dog__140203.mp3': 27, 'dog__82807.mp3': 29, 'game__237071.mp3': 26, 'game__302107.mp3': 32, 'girl_2.mp3': 28, 'girl__445999.mp3': 31, 'kite__124442.mp3': 21, 'kite__289960.mp3': 22, 'kite__478721.mp3': 25, 'kite__511647.mp3': 30, 'kite__7511.mp3': 22, 'person__35197.mp3': 36, 'person__460841.mp3': 28, 'person__534601.mp3': 27, 'person__8021.mp3': 29, 'pizza_1.mp3': 30, 'pizza_2.mp3': 27, 'pizza__161925.mp3': 30, 'pizza__385029.mp3': 27, 'table__142620.mp3': 25, 'table__329455.mp3': 27, 'table__405691.mp3': 25, 'table__87742.mp3': 28, 'tennis__117744.mp3': 26, 'tennis__379332.mp3': 28, 'tennis__404922.mp3': 41, 'tennis__515828.mp3': 27}

# %%
#import the phoneme and features representations to separte each MP3 from another and complie them in dictionaries 

import numpy as np 
T = np.load("test_mfcc_phonemes.npy")
L = np.load("test_mfcc_features.npy")

L.shape[0]
# Out:
# 2608

# %%
orig_manips = dict(**PHO_org, **PHO_manips)
both_mp3_pho={}
both_mp3_features ={}

start = 0
end = orig_manips[data.iloc[0]['path']]

for index, row in data.iterrows():
    if index+1 < len(data['path']):
        both_mp3_pho[row['path']]=T[start:end]
        both_mp3_features[row['path']] = L[start:end]
        start = end 
        end = start + orig_manips[data.iloc[index+1]['path']]

        
both_mp3_pho['tog__82807.mp3'] = T[2579:]    #out of index, last MP3 
both_mp3_features['tog__82807.mp3'] = L[2579:]   #out of index, last MP3 


both_mp3_pho
# Out:
# {'beetza_1.mp3': array(['t', 'uw', 'w', 'ih', 'm', 'ah', 'n', 'ae', 'n', 'd', 't', 'uw',
#         'm', 'eh', 'n', 's', 'm', 'ay', 'l', 'ih', 'ng', 'ow', 'v', 'er',
#         'ah', 'p', 'iy', 't', 's', 'ah'], dtype='<U2'),
#  'beetza_161925.mp3': array(['t', 'uw', 'w', 'ih', 'm', 'ah', 'n', 'er', 'k', 'ah', 't', 'ih',
#         'ng', 'ae', 'n', 'd', 'p', 'r', 'iy', 'p', 'eh', 'r', 'ih', 'ng',
#         'ah', 'p', 'iy', 't', 's', 'ah'], dtype='<U2'),
#  'beetza_2.mp3': array(['ah', 'w', 'uh', 'm', 'ah', 'n', 'ih', 'n', 'ah', 'b', 'l', 'ae',
#         'k', 'jh', 'ae', 'k', 'ih', 't', 'ae', 'n', 'd', 'ah', 'p', 'iy',
#         't', 's', 'ah'], dtype='<U2'),
#  'beetza_385029.mp3': array(['ah', 'hh', 'ae', 'n', 'd', 'ih', 'z', 's', 'l', 'ay', 's', 'ih',
#         'ng', 'ah', 'p', 'iy', 't', 's', 'ah', 'ao', 'n', 'ah', 't', 'ey',
#         'b', 'ah', 'l'], dtype='<U2'),
#  'bench__227478.mp3': array(['t', 'uw', 'p', 'iy', 'p', 'ah', 'l', 's', 'ih', 't', 'ih', 'ng',
#         'ao', 'n', 'ah', 'b', 'eh', 'n', 'ch', 'n', 'ih', 'r', 't', 'r',
#         'iy', 'z'], dtype='<U2'),
#  'bench__349184.mp3': array(['ah', 'w', 'uh', 'm', 'ah', 'n', 's', 'ih', 't', 's', 'aa', 'n',
#         'ah', 'b', 'eh', 'n', 'ch', 'w', 'aa', 'ch', 'ih', 'ng', 'dh',
#         'ah', 'p', 'aa', 'r', 'k'], dtype='<U2'),
#  'bench__464251.mp3': array(['ah', 'n', 'ay', 's', 'b', 'er', 'd', 's', 't', 'ae', 'n', 'd',
#         'ih', 'ng', 'ao', 'n', 'ah', 'b', 'eh', 'n', 'ch', 'g', 'ey', 'z',
#         'ih', 'ng', 'ae', 't'], dtype='<U2'),
#  'bench__89697.mp3': array(['dh', 'ih', 's', 'w', 'uh', 'm', 'ah', 'n', 'ih', 'z', 's', 'ih',
#         't', 'ih', 'ng', 'ao', 'n', 'ah', 'w', 'uh', 'd', 'b', 'eh', 'n',
#         'ch'], dtype='<U2'),
#  'berson__35197.mp3': array(['b', 'l', 'ae', 'k', 'ah', 'n', 'd', 'w', 'ay', 't', 'f', 'ow',
#         't', 'ah', 'g', 'r', 'ae', 'f', 'ah', 'v', 'p', 'er', 's', 'ah',
#         'n', 'ao', 'n', 'ah', 's', 'k', 'ey', 't', 'b', 'ao', 'r', 'd'],
#        dtype='<U2'),
#  'berson__460841.mp3': array(['ah', 'k', 'ae', 't', 'l', 'uh', 'k', 's', 'ae', 't', 'ah', 'p',
#         'er', 's', 'ah', 'n', 'hh', 'ow', 'l', 'd', 'ih', 'ng', 'ah', 'b',
#         'aa', 't', 'ah', 'l'], dtype='<U2'),
#  'berson__534601.mp3': array(['ah', 's', 't', 'ah', 'f', 't', 't', 'eh', 'd', 'iy', 'b', 'eh',
#         'r', 'w', 'ih', 'th', 'ah', 'p', 'er', 's', 'ah', 'n', 'ih', 'n',
#         'b', 'eh', 'd'], dtype='<U2'),
#  'berson__8021.mp3': array(['ah', 'l', 'aa', 'r', 'jh', 's', 'k', 'r', 'iy', 'n', 'sh', 'ow',
#         'ih', 'ng', 'ah', 'p', 'er', 's', 'ah', 'n', 'w', 'eh', 'r', 'ih',
#         'ng', 'ah', 's', 'uw', 't'], dtype='<U2'),
#  'boat.mp3': array(['dh', 'eh', 'r', 'er', 't', 'uw', 'm', 'eh', 'n', 'ih', 'n', 'ah',
#         'n', 'aa', 'd', 'l', 'uh', 'k', 'ih', 'ng', 'b', 'ow', 't'],
#        dtype='<U2'),
#  'boat__116439.mp3': array(['ah', 'w', 'uh', 'm', 'ah', 'n', 'r', 'ay', 'd', 'ih', 'ng', 'ih',
#         'n', 'ah', 'b', 'ow', 't', 'd', 'aw', 'n', 'ah', 'r', 'ih', 'v',
#         'er'], dtype='<U2'),
#  'boat__160728.mp3': array(['p', 'iy', 'p', 'ah', 'l', 'ae', 't', 'dh', 'ah', 'b', 'iy', 'ch',
#         'b', 'r', 'ih', 'ng', 'ih', 'ng', 'dh', 'eh', 'r', 'b', 'ow', 't',
#         'ih', 'n'], dtype='<U2'),
#  'boat__570448.mp3': array(['ah', 'm', 'ae', 'n', 's', 't', 'ae', 'n', 'd', 'ih', 'ng', 'ih',
#         'n', 'ah', 'b', 'ow', 't', 'n', 'ih', 'r', 'sh', 'ao', 'r'],
#        dtype='<U2'),
#  'cake.mp3': array(['ah', 'n', 'ih', 'm', 'ih', 'jh', 'ah', 'v', 'ah', 'w', 'uh', 'm',
#         'ah', 'n', 'hh', 'ow', 'l', 'd', 'ih', 'ng', 'ah', 'k', 'ey', 'k'],
#        dtype='<U2'),
#  'cake__155179.mp3': array(['ah', 'n', 'f', 'ow', 't', 'ow', 'ah', 'v', 'ey', 'k', 'ey', 'k',
#         'w', 'ih', 'th', 'ch', 'ao', 'k', 'l', 'ah', 't', 'p', 'iy', 's',
#         'ih', 'z'], dtype='<U2'),
#  'cake__334483.mp3': array(['p', 'iy', 'p', 'ah', 'l', 'aw', 't', 's', 'ay', 'd', 'ae', 't',
#         't', 'ey', 'b', 'ah', 'l', 'iy', 't', 'ih', 'ng', 'k', 'ey', 'k',
#         'ao', 'n', 'p', 'l', 'ey', 't', 's'], dtype='<U2'),
#  'cake__405249.mp3': array(['m', 'eh', 'n', 'iy', 'p', 'iy', 'p', 'ah', 'l', 'er', 'aw', 'n',
#         'd', 'ah', 'ch', 'ao', 'k', 'l', 'ah', 't', 'b', 'er', 'th', 'd',
#         'ey', 'k', 'ey', 'k', 'w', 'ih', 'th', 'k', 'ae', 'n', 'd', 'ah',
#         'l', 'z'], dtype='<U2'),
#  'dable__142620.mp3': array(['ah', 'm', 'ae', 'n', 'iy', 't', 'ih', 'ng', 'aw', 't', 'ao', 'n',
#         'ah', 't', 'ey', 'b', 'ah', 'l', 'ah', 'n', 'd', 'b', 'eh', 'n',
#         'ch'], dtype='<U2'),
#  'dable__329455.mp3': array(['ah', 'v', 'eh', 'r', 'iy', 'l', 'aa', 'r', 'jh', 'p', 'iy', 't',
#         's', 'ah', 'ao', 'n', 'ah', 'w', 'uh', 'd', 'ah', 'n', 't', 'ey',
#         'b', 'ah', 'l'], dtype='<U2'),
#  'dable__405691.mp3': array(['dh', 'eh', 'r', 'ih', 'z', 'w', 'ay', 'n', 'ae', 'n', 'd', 'b',
#         'r', 'eh', 'd', 'ao', 'n', 'dh', 'ih', 's', 't', 'ey', 'b', 'ah',
#         'l'], dtype='<U2'),
#  'dable__87742.mp3': array(['ah', 'g', 'l', 'ae', 's', 'v', 'aa', 'z', 'f', 'ih', 'l', 'd',
#         'w', 'ih', 'th', 'f', 'eh', 'dh', 'er', 'z', 'ao', 'n', 'ah', 't',
#         'ey', 'b', 'ah', 'l'], dtype='<U2'),
#  'day_1.mp3': array(['ah', 'z', 'iy', 'b', 'r', 'ah', 'ih', 'n', 'dh', 'ah', 'sh', 'ey',
#         'd', 'ao', 'n', 'ah', 's', 'ah', 'n', 'iy', 'd', 'ey'], dtype='<U2'),
#  'day_2.mp3': array(['ah', 'g', 'er', 'l', 't', 'aa', 'd', 'l', 'er', 'l', 'ey', 'ih',
#         'ng', 'ao', 'n', 'ah', 'd', 'ey', 'b', 'eh', 'd'], dtype='<U2'),
#  'day__179392.mp3': array(['k', 'ae', 't', 's', 't', 'eh', 'r', 'ih', 'ng', 'ih', 'n', 't',
#         'ah', 'dh', 'ah', 'k', 'ae', 'm', 'er', 'ah', 'ih', 'n', 'dh',
#         'ah', 'd', 'ey', 't', 'ay', 'm'], dtype='<U2'),
#  'day__312237.mp3': array(['p', 'iy', 'p', 'ah', 'l', 'ae', 't', 'dh', 'ah', 'b', 'iy', 'ch',
#         'ih', 'n', 'jh', 'oy', 'ih', 'ng', 'dh', 'ah', 'd', 'ey', 'ae',
#         'n', 'd', 's', 'er', 'f', 'ih', 'ng'], dtype='<U2'),
#  'dennis__117744.mp3': array(['ah', 'ch', 'ay', 'l', 'd', 'ih', 'z', 'p', 'ow', 'z', 'ih', 'ng',
#         'w', 'ih', 'th', 'ah', 't', 'eh', 'n', 'ih', 's', 'r', 'ae', 'k',
#         'ih', 't'], dtype='<U2'),
#  'dennis__379332.mp3': array(['ah', 'm', 'ae', 'n', 'ao', 'n', 'ah', 'k', 'ao', 'r', 't', 's',
#         'w', 'ih', 'ng', 'ih', 'ng', 'ah', 't', 'eh', 'n', 'ih', 's', 'r',
#         'ae', 'k', 'ih', 't'], dtype='<U2'),
#  'dennis__404922.mp3': array(['ah', 'n', 'ae', 'd', 'ah', 'l', 't', 'w', 'ao', 'k', 'ih', 'ng',
#         'w', 'ih', 'th', 't', 'uw', 'ch', 'ih', 'l', 'd', 'r', 'ah', 'n',
#         'hh', 'ow', 'l', 'd', 'ih', 'ng', 't', 'eh', 'n', 'ih', 's', 'r',
#         'ae', 'k', 'ah', 't', 's'], dtype='<U2'),
#  'dennis__515828.mp3': array(['ah', 'w', 'uh', 'm', 'ah', 'n', 'p', 'r', 'iy', 'p', 'eh', 'r',
#         'z', 't', 'ih', 's', 'er', 'v', 'ah', 't', 'eh', 'n', 'ih', 's',
#         'b', 'ao', 'l'], dtype='<U2'),
#  'dog_1.mp3': array(['ah', 'k', 'l', 'ow', 's', 'ah', 'p', 'ah', 'v', 'ey', 'd', 'ao',
#         'g', 'ao', 'n', 'ah', 'b', 'ow', 't'], dtype='<U2'),
#  'dog_2.mp3': array(['ah', 'm', 'ae', 'n', 'ao', 'n', 'ah', 's', 'k', 'ey', 't', 'b',
#         'ao', 'r', 'd', 'w', 'ih', 'th', 'ah', 'd', 'ao', 'g', 'aw', 't',
#         's', 'ay', 'd'], dtype='<U2'),
#  'dog__140203.mp3': array(['w', 'uh', 'm', 'ah', 'n', 'ih', 'z', 'w', 'ao', 'k', 'ih', 'ng',
#         'w', 'ih', 'th', 'ah', 'd', 'ao', 'g', 'ih', 'n', 'hh', 'er', 'hh',
#         'ae', 'n', 'z'], dtype='<U2'),
#  'dog__82807.mp3': array(['ah', 'v', 'eh', 'r', 'iy', 'k', 'y', 'uw', 't', 'l', 'uh', 'k',
#         'ih', 'ng', 's', 'm', 'ao', 'l', 'd', 'ao', 'g', 'b', 'ay', 's',
#         'ah', 'm', 'f', 'uw', 'd'], dtype='<U2'),
#  'game.mp3': array(['ah', 's', 'm', 'ao', 'l', 'g', 'er', 'l', 'p', 'l', 'ey', 'z',
#         'ah', 'g', 'ey', 'm', 'ah', 'v'], dtype='<U2'),
#  'game__12639.mp3': array(['ah', 'b', 'oy', 'hh', 'ow', 'l', 'd', 'ih', 'ng', 'ah', 'b', 'ae',
#         't', 'ae', 't', 'ah', 'g', 'ey', 'm'], dtype='<U2'),
#  'game__237071.mp3': array(['dh', 'iy', 'y', 'ah', 'ng', 'm', 'ae', 'n', 'ih', 'z', 'p', 'l',
#         'ey', 'ih', 'ng', 'ah', 'g', 'ey', 'm', 'ah', 'v', 't', 'eh', 'n',
#         'ah', 's'], dtype='<U2'),
#  'game__302107.mp3': array(['t', 'uw', 'ae', 'th', 'l', 'iy', 't', 's', 'ae', 'k', 't', 'ih',
#         'v', 'l', 'iy', 'p', 'l', 'ey', 'ih', 'ng', 'ah', 'g', 'ey', 'm',
#         'ah', 'v', 'b', 'ey', 's', 'b', 'ao', 'l'], dtype='<U2'),
#  'gayk.mp3': array(['ah', 'n', 'ih', 'm', 'ih', 'jh', 'ah', 'v', 'ey', 'w', 'uh', 'm',
#         'ah', 'n', 'hh', 'ow', 'l', 'd', 'ih', 'ng', 'ah', 'k', 'ey', 'k'],
#        dtype='<U2'),
#  'gayk__155179.mp3': array(['ah', 'n', 'f', 'ow', 't', 'ow', 'ah', 'v', 'ey', 'k', 'ey', 'k',
#         'w', 'ih', 'th', 'ch', 'ao', 'k', 'l', 'ah', 't', 'p', 'iy', 's',
#         'ih', 'z'], dtype='<U2'),
#  'gayk__334483.mp3': array(['p', 'iy', 'p', 'ah', 'l', 'aw', 't', 's', 'ay', 'd', 'ae', 't',
#         't', 'ey', 'b', 'ah', 'l', 'iy', 't', 'ih', 'ng', 'k', 'ey', 'k',
#         'aa', 'n', 'p', 'l', 'ey', 't', 's'], dtype='<U2'),
#  'gayk__405249.mp3': array(['m', 'eh', 'n', 'iy', 'p', 'iy', 'p', 'ah', 'l', 'er', 'aw', 'n',
#         'd', 'ah', 'ch', 'ao', 'k', 'l', 'ah', 't', 'b', 'er', 'th', 'd',
#         'ey', 'k', 'ey', 'k', 'w', 'ih', 'th', 'k', 'ae', 'n', 'd', 'ah',
#         'l', 'z'], dtype='<U2'),
#  'girl_1.mp3': array(['dh', 'eh', 'r', 'ih', 'z', 'ah', 'm', 'ae', 'n', 'ae', 'n', 'd',
#         'ey', 'y', 'ah', 'ng', 'g', 'er', 'l'], dtype='<U2'),
#  'girl_2.mp3': array(['ah', 'm', 'ae', 'n', 'hh', 'ow', 'l', 'd', 'ih', 'ng', 'ao', 'n',
#         't', 'uw', 'ah', 'l', 'ih', 't', 'ah', 'l', 'b', 'l', 'aa', 'n',
#         'd', 'g', 'er', 'l'], dtype='<U2'),
#  'girl__445999.mp3': array(['ah', 'p', 'r', 'ih', 't', 'iy', 'y', 'ah', 'ng', 'd', 'aa', 'r',
#         'k', 'hh', 'eh', 'r', 'd', 'g', 'er', 'l', 'b', 'r', 'ah', 'sh',
#         'ih', 'ng', 'hh', 'er', 't', 'iy', 'th'], dtype='<U2'),
#  'girl__546475.mp3': array(['ah', 'm', 'ae', 'n', 'ae', 'n', 'd', 'hh', 'ih', 'z', 'b', 'ey',
#         'b', 'iy', 'g', 'er', 'l', 't', 'ey', 'k', 'ih', 'ng', 'ah'],
#        dtype='<U2'),
#  'guyte__124442.mp3': array(['ah', 'm', 'ae', 'n', 'ih', 'z', 'f', 'l', 'ay', 'ih', 'ng', 'ah',
#         'k', 'ay', 't', 'ao', 'n', 'ah', 'b', 'iy', 'ch'], dtype='<U2'),
#  'guyte__289960.mp3': array(['ah', 'm', 'ae', 'n', 'ih', 'z', 'f', 'l', 'ay', 'ih', 'ng', 'ah',
#         'k', 'ay', 't', 'ae', 't', 'dh', 'ah', 'b', 'iy', 'ch'],
#        dtype='<U2'),
#  'guyte__478721.mp3': array(['t', 'uw', 'b', 'oy', 'z', 'k', 'eh', 'r', 'ih', 'ng', 'ah', 'b',
#         'ih', 'g', 'k', 'ay', 't', 't', 'ay', 'p', 'ah', 'v', 'th', 'ih',
#         'ng'], dtype='<U2'),
#  'guyte__511647.mp3': array(['ah', 'p', 'er', 's', 'ah', 'n', 'ih', 'z', 'f', 'l', 'ay', 'ih',
#         'ng', 'ah', 'k', 'ay', 't', 'n', 'ih', 'r', 's', 'ah', 'm', 'b',
#         'ih', 'l', 'd', 'ih', 'ng', 'z'], dtype='<U2'),
#  'guyte__7511.mp3': array(['ah', 'm', 'ae', 'n', 'ih', 'z', 'f', 'l', 'ay', 'ih', 'ng', 'ah',
#         'k', 'ay', 't', 'ae', 't', 'dh', 'ah', 'b', 'iy', 'ch'],
#        dtype='<U2'),
#  'kame.mp3': array(['ah', 's', 'm', 'ao', 'l', 'g', 'er', 'l', 'p', 'l', 'ey', 'z',
#         'ah', 'g', 'ey', 'm', 'ah', 'v'], dtype='<U2'),
#  'kame__12639.mp3': array(['ah', 'b', 'oy', 'hh', 'ow', 'l', 'd', 'ih', 'ng', 'ah', 'b', 'ae',
#         't', 'ae', 't', 'ah', 'g', 'ey', 'm'], dtype='<U2'),
#  'kame__237071.mp3': array(['dh', 'iy', 'y', 'ah', 'ng', 'm', 'ae', 'n', 'ih', 'z', 'p', 'l',
#         'ey', 'ih', 'ng', 'ah', 'g', 'ey', 'm', 'ah', 'v', 't', 'eh', 'n',
#         'ih', 's'], dtype='<U2'),
#  'kame__302107.mp3': array(['t', 'uw', 'ae', 'th', 'l', 'iy', 't', 's', 'ae', 'k', 't', 'ih',
#         'v', 'l', 'iy', 'p', 'l', 'ey', 'ih', 'ng', 'ah', 'g', 'ey', 'm',
#         'ah', 'v', 'b', 'ey', 's', 'b', 'ao', 'l'], dtype='<U2'),
#  'kirl_1.mp3': array(['dh', 'eh', 'r', 'ih', 'z', 'ah', 'm', 'ae', 'n', 'ae', 'n', 'd',
#         'ey', 'y', 'ah', 'ng', 'g', 'er', 'l'], dtype='<U2'),
#  'kirl_2.mp3': array(['ah', 'm', 'ae', 'n', 'hh', 'ow', 'l', 'd', 'ih', 'ng', 'ao', 'n',
#         't', 'uw', 'ah', 'l', 'ih', 't', 'ah', 'l', 'b', 'l', 'aa', 'n',
#         'd', 'g', 'er', 'l'], dtype='<U2'),
#  'kirl__445999.mp3': array(['ah', 'p', 'r', 'ih', 't', 'iy', 'y', 'ah', 'ng', 'd', 'aa', 'r',
#         'k', 'hh', 'eh', 'r', 'd', 'g', 'er', 'l', 'b', 'r', 'ah', 'sh',
#         'ih', 'ng', 'hh', 'er', 't', 'iy', 'th'], dtype='<U2'),
#  'kirl__546475.mp3': array(['ah', 'm', 'ae', 'n', 'ae', 'n', 'd', 'hh', 'ih', 'z', 'b', 'ey',
#         'b', 'iy', 'g', 'er', 'l', 't', 'ey', 'k', 'ih', 'ng', 'ah'],
#        dtype='<U2'),
#  'kite__124442.mp3': array(['ah', 'm', 'ae', 'n', 'ih', 'z', 'f', 'l', 'ay', 'ih', 'ng', 'ah',
#         'k', 'ay', 't', 'ao', 'n', 'ah', 'b', 'iy', 'ch'], dtype='<U2'),
#  'kite__289960.mp3': array(['ah', 'm', 'ae', 'n', 'ih', 'z', 'f', 'l', 'ay', 'ih', 'ng', 'ah',
#         'k', 'ay', 't', 'ae', 't', 'dh', 'ah', 'b', 'iy', 'ch'],
#        dtype='<U2'),
#  'kite__478721.mp3': array(['t', 'uw', 'b', 'oy', 'z', 'k', 'eh', 'r', 'ih', 'ng', 'ah', 'b',
#         'ih', 'g', 'k', 'ay', 't', 't', 'ay', 'p', 'ah', 'v', 'th', 'ih',
#         'ng'], dtype='<U2'),
#  'kite__511647.mp3': array(['ah', 'p', 'er', 's', 'ah', 'n', 'ih', 'z', 'f', 'l', 'ay', 'ih',
#         'ng', 'ah', 'k', 'ay', 't', 'n', 'ih', 'r', 's', 'ah', 'm', 'b',
#         'ih', 'l', 'd', 'ih', 'ng', 'z'], dtype='<U2'),
#  'kite__7511.mp3': array(['ah', 'm', 'ae', 'n', 'ih', 'z', 'f', 'l', 'ay', 'ih', 'ng', 'ah',
#         'k', 'ay', 't', 'ae', 't', 'dh', 'ah', 'b', 'iy', 'ch'],
#        dtype='<U2'),
#  'pench__227478.mp3': array(['t', 'uw', 'p', 'iy', 'p', 'ah', 'l', 's', 'ih', 't', 'ih', 'ng',
#         'ao', 'n', 'ah', 'b', 'eh', 'n', 'ch', 'n', 'ih', 'r', 't', 'r',
#         'iy', 'z'], dtype='<U2'),
#  'pench__349184.mp3': array(['ah', 'w', 'uh', 'm', 'ah', 'n', 's', 'ih', 't', 's', 'aa', 'n',
#         'ah', 'b', 'eh', 'n', 'ch', 'w', 'aa', 'ch', 'ih', 'ng', 'dh',
#         'ah', 'p', 'aa', 'r', 'k'], dtype='<U2'),
#  'pench__464251.mp3': array(['ah', 'n', 'ay', 's', 'b', 'er', 'd', 's', 't', 'ae', 'n', 'd',
#         'ih', 'ng', 'ao', 'n', 'ah', 'b', 'eh', 'n', 'ch', 'g', 'ey', 'z',
#         'ih', 'ng', 'ae', 't'], dtype='<U2'),
#  'pench__89697.mp3': array(['dh', 'ih', 's', 'w', 'uh', 'm', 'ah', 'n', 'ih', 'z', 's', 'ih',
#         't', 'ih', 'ng', 'ao', 'n', 'ah', 'w', 'uh', 'd', 'b', 'eh', 'n',
#         'ch'], dtype='<U2'),
#  'person__35197.mp3': array(['b', 'l', 'ae', 'k', 'ah', 'n', 'd', 'w', 'ay', 't', 'f', 'ow',
#         't', 'ah', 'g', 'r', 'ae', 'f', 'ah', 'v', 'p', 'er', 's', 'ah',
#         'n', 'ao', 'n', 'ah', 's', 'k', 'ey', 't', 'b', 'ao', 'r', 'd'],
#        dtype='<U2'),
#  'person__460841.mp3': array(['ah', 'k', 'ae', 't', 'l', 'uh', 'k', 's', 'ae', 't', 'ah', 'p',
#         'er', 's', 'ah', 'n', 'hh', 'ow', 'l', 'd', 'ih', 'ng', 'ah', 'b',
#         'aa', 't', 'ah', 'l'], dtype='<U2'),
#  'person__534601.mp3': array(['ah', 's', 't', 'ah', 'f', 't', 't', 'eh', 'd', 'iy', 'b', 'eh',
#         'r', 'w', 'ih', 'dh', 'ah', 'p', 'er', 's', 'ah', 'n', 'ih', 'n',
#         'b', 'eh', 'd'], dtype='<U2'),
#  'person__8021.mp3': array(['ah', 'l', 'aa', 'r', 'jh', 's', 'k', 'r', 'iy', 'n', 'sh', 'ow',
#         'ih', 'ng', 'ah', 'p', 'er', 's', 'ah', 'n', 'w', 'eh', 'r', 'ih',
#         'ng', 'ah', 's', 'uw', 't'], dtype='<U2'),
#  'pizza_1.mp3': array(['t', 'uw', 'w', 'ih', 'm', 'ah', 'n', 'ae', 'n', 'd', 't', 'uw',
#         'm', 'eh', 'n', 's', 'm', 'ay', 'l', 'ih', 'ng', 'ow', 'v', 'er',
#         'ah', 'p', 'iy', 't', 's', 'ah'], dtype='<U2'),
#  'pizza_2.mp3': array(['ah', 'w', 'uh', 'm', 'ah', 'n', 'ih', 'n', 'ah', 'b', 'l', 'ae',
#         'k', 'jh', 'ae', 'k', 'ih', 't', 'ae', 'n', 'd', 'ah', 'p', 'iy',
#         't', 's', 'ah'], dtype='<U2'),
#  'pizza__161925.mp3': array(['t', 'uw', 'w', 'ih', 'm', 'ah', 'n', 'er', 'k', 'ah', 't', 'ih',
#         'ng', 'ae', 'n', 'd', 'p', 'r', 'iy', 'p', 'eh', 'r', 'ih', 'ng',
#         'ah', 'p', 'iy', 't', 's', 'ah'], dtype='<U2'),
#  'pizza__385029.mp3': array(['ah', 'hh', 'ae', 'n', 'd', 'ih', 'z', 's', 'l', 'ay', 's', 'ih',
#         'ng', 'ah', 'p', 'iy', 't', 's', 'ah', 'ao', 'n', 'ah', 't', 'ey',
#         'b', 'ah', 'l'], dtype='<U2'),
#  'poat.mp3': array(['dh', 'eh', 'r', 'er', 't', 'uw', 'm', 'eh', 'n', 'ih', 'n', 'ah',
#         'n', 'aa', 'd', 'l', 'uh', 'k', 'ih', 'ng', 'b', 'ow', 't'],
#        dtype='<U2'),
#  'poat__116439.mp3': array(['ah', 'w', 'uh', 'm', 'ah', 'n', 'r', 'ay', 'd', 'ih', 'ng', 'ih',
#         'n', 'ah', 'b', 'ow', 't', 'd', 'aw', 'n', 'ah', 'r', 'ih', 'v',
#         'er'], dtype='<U2'),
#  'poat__160728.mp3': array(['p', 'iy', 'p', 'ah', 'l', 'ae', 't', 'dh', 'ah', 'b', 'iy', 'ch',
#         'b', 'r', 'ih', 'ng', 'ih', 'ng', 'dh', 'eh', 'r', 'b', 'ow', 't',
#         'ih', 'n'], dtype='<U2'),
#  'poat__570448.mp3': array(['ah', 'm', 'ae', 'n', 's', 't', 'ae', 'n', 'd', 'ih', 'ng', 'ih',
#         'n', 'ah', 'b', 'ow', 't', 'n', 'ih', 'r', 'sh', 'ao', 'r'],
#        dtype='<U2'),
#  'table__142620.mp3': array(['ah', 'm', 'ae', 'n', 'iy', 't', 'ih', 'ng', 'aw', 't', 'ao', 'n',
#         'ah', 't', 'ey', 'b', 'ah', 'l', 'ae', 'n', 'd', 'b', 'eh', 'n',
#         'ch'], dtype='<U2'),
#  'table__329455.mp3': array(['ah', 'v', 'eh', 'r', 'iy', 'l', 'aa', 'r', 'jh', 'p', 'iy', 't',
#         's', 'ah', 'ao', 'n', 'ah', 'w', 'uh', 'd', 'ah', 'n', 't', 'ey',
#         'b', 'ah', 'l'], dtype='<U2'),
#  'table__405691.mp3': array(['dh', 'eh', 'r', 'ih', 'z', 'w', 'ay', 'n', 'ae', 'n', 'd', 'b',
#         'r', 'eh', 'd', 'ao', 'n', 'dh', 'ih', 's', 't', 'ey', 'b', 'ah',
#         'l'], dtype='<U2'),
#  'table__87742.mp3': array(['ah', 'g', 'l', 'ae', 's', 'v', 'aa', 'z', 'f', 'ih', 'l', 'd',
#         'w', 'ih', 'th', 'f', 'eh', 'dh', 'er', 'z', 'aa', 'n', 'ah', 't',
#         'ey', 'b', 'ah', 'l'], dtype='<U2'),
#  'tay_1.mp3': array(['ah', 'z', 'iy', 'b', 'r', 'ah', 'ih', 'n', 'dh', 'ah', 'sh', 'ey',
#         'd', 'ao', 'n', 'ah', 's', 'ah', 'n', 'iy', 'd', 'ey'], dtype='<U2'),
#  'tay_2.mp3': array(['ah', 'g', 'er', 'l', 't', 'aa', 'd', 'l', 'er', 'l', 'ey', 'ih',
#         'ng', 'ao', 'n', 'ah', 'd', 'ey', 'b', 'eh', 'd'], dtype='<U2'),
#  'tay__179392.mp3': array(['k', 'ae', 't', 's', 't', 'eh', 'r', 'ih', 'ng', 'ih', 'n', 't',
#         'ah', 'dh', 'ah', 'k', 'ae', 'm', 'er', 'ah', 'ih', 'n', 'dh',
#         'ah', 'd', 'ey', 't', 'ay', 'm'], dtype='<U2'),
#  'tay__312237.mp3': array(['p', 'iy', 'p', 'ah', 'l', 'ae', 't', 'dh', 'ah', 'b', 'iy', 'ch',
#         'ih', 'n', 'jh', 'oy', 'ih', 'ng', 'dh', 'ah', 'd', 'ey', 'ae',
#         'n', 'd', 's', 'er', 'f', 'ih', 'ng'], dtype='<U2'),
#  'tennis__117744.mp3': array(['ah', 'ch', 'ay', 'l', 'd', 'ih', 'z', 'p', 'ow', 'z', 'ih', 'ng',
#         'w', 'ih', 'th', 'ah', 't', 'eh', 'n', 'ih', 's', 'r', 'ae', 'k',
#         'ih', 't'], dtype='<U2'),
#  'tennis__379332.mp3': array(['ah', 'm', 'ae', 'n', 'ao', 'n', 'ah', 'k', 'ao', 'r', 't', 's',
#         'w', 'ih', 'ng', 'ih', 'ng', 'ah', 't', 'eh', 'n', 'ih', 's', 'r',
#         'ae', 'k', 'ih', 't'], dtype='<U2'),
#  'tennis__404922.mp3': array(['ah', 'n', 'ae', 'd', 'ah', 'l', 't', 'w', 'ao', 'k', 'ih', 'ng',
#         'w', 'ih', 'th', 't', 'uw', 'ch', 'ih', 'l', 'd', 'r', 'ah', 'n',
#         'hh', 'ow', 'l', 'd', 'ih', 'ng', 't', 'eh', 'n', 'ih', 's', 'r',
#         'ae', 'k', 'ah', 't', 's'], dtype='<U2'),
#  'tennis__515828.mp3': array(['ah', 'w', 'uh', 'm', 'ah', 'n', 'p', 'r', 'iy', 'p', 'eh', 'r',
#         'z', 't', 'ih', 's', 'er', 'v', 'ah', 't', 'eh', 'n', 'ih', 's',
#         'b', 'ao', 'l'], dtype='<U2'),
#  'tog_1.mp3': array(['ah', 'k', 'l', 'ow', 's', 'ah', 'p', 'ah', 'v', 'ah', 'd', 'ao',
#         'g', 'ao', 'n', 'ah', 'b', 'ow', 't'], dtype='<U2'),
#  'tog_2.mp3': array(['ah', 'm', 'ae', 'n', 'ao', 'n', 'ah', 's', 'k', 'ey', 't', 'b',
#         'ao', 'r', 'd', 'w', 'ih', 'dh', 'ey', 'd', 'ao', 'g', 'aw', 't',
#         's', 'ay', 'd'], dtype='<U2'),
#  'tog__140203.mp3': array(['w', 'uh', 'm', 'ah', 'n', 'ih', 'z', 'w', 'ao', 'k', 'ih', 'ng',
#         'w', 'ih', 'th', 'ey', 'd', 'ao', 'g', 'ih', 'n', 'hh', 'er', 'hh',
#         'ae', 'n', 'z'], dtype='<U2'),
#  'tog__82807.mp3': array(['ah', 'v', 'eh', 'r', 'iy', 'k', 'y', 'uw', 't', 'l', 'uh', 'k',
#         'ih', 'ng', 's', 'm', 'ao', 'l', 'd', 'ao', 'g', 'b', 'ay', 's',
#         'ah', 'm', 'f', 'uw', 'd'], dtype='<U2')}

# %%
#create a dictionary of MP3 name and the phonemes prefix of the specific word as its value 

both_mp3_prefix={}

for element in both_mp3_pho:
    x =element.split('_')[0].split('.')[0]
    if x =='beetza' or x=='pizza':
        both_mp3_prefix[element]='piy'
    if x =='bench' or x=='pench':
        both_mp3_prefix[element]='beh'
    if x =='berson' or x=='person':
        both_mp3_prefix[element]='per'
    if x =='boat' or x=='poat':
        both_mp3_prefix[element]='bow'
    if x =='cake' or x=='gayk':
        both_mp3_prefix[element]='key'
    if x =='dable' or x=='table':
        both_mp3_prefix[element]='tey'
    if x =='day' or x=='tay':
        both_mp3_prefix[element]='dey'
    if x =='dennis' or x=='tennis':
        both_mp3_prefix[element]='teh'
    if x =='dog' or x=='tog':
        both_mp3_prefix[element]='dao'
    if x =='game' or x=='kame':
        both_mp3_prefix[element]='gey'
    if x =='girl' or x=='kirl':
        both_mp3_prefix[element]='ger'
    if x =='guyte' or x=='kite':
        both_mp3_prefix[element]='kay'

# %%
#define an indexing fonction to find the index of the phoneme of interest 
def find_index(a,b):
    for index,pho in np.ndenumerate(both_mp3_pho[a]):
        if index[0]+1<len(both_mp3_pho[a]):
            X = np.core.defchararray.add(pho,both_mp3_pho[a][index[0]+1])
            if X== b:
                return index[0]
                
#parse through MP3s phoneme dictionary to find the index of the specific phoneme in each array of phonemes
#create a dcitionary for each mp3 and the index of the phoneme of interest 

mp3_pho_idx={}

for mp3 in both_mp3_prefix:
    mp3_pho_idx[mp3]=find_index(mp3,both_mp3_prefix[mp3])

# %%
#list of tuples of mp3 matching pairs
#create a list of tuples of matching mp3s (each mp3 and its counterpart with the manipulated end word)

matching_mp3 = [('beetza_1.mp3', 'pizza_1.mp3'),('beetza_161925.mp3','pizza__161925.mp3'), ('beetza_2.mp3','pizza_2.mp3'),
               ('beetza_385029.mp3', 'pizza__385029.mp3'),('bench__227478.mp3','pench__227478.mp3'),
               ('bench__349184.mp3','pench__349184.mp3'),('bench__464251.mp3','pench__464251.mp3'),
               ('bench__89697.mp3','pench__89697.mp3'), ('berson__35197.mp3', 'person__35197.mp3'),
               ('berson__460841.mp3','person__460841.mp3'),('berson__534601.mp3','person__534601.mp3'),
               ('berson__8021.mp3','person__8021.mp3'), ('boat.mp3','poat.mp3'), ('boat__116439.mp3','poat__116439.mp3'),
                ('boat__160728.mp3', 'poat__160728.mp3'),('boat__570448.mp3','poat__570448.mp3'),('cake.mp3','gayk.mp3') 
                ,('cake__155179.mp3', 'gayk__155179.mp3'), ('cake__334483.mp3', 'gayk__334483.mp3'),
                ('cake__405249.mp3','gayk__405249.mp3' ), ('dable__142620.mp3', 'table__142620.mp3' ), 
                ('dable__329455.mp3','table__329455.mp3'),('dable__405691.mp3','table__405691.mp3'),
                ('dable__87742.mp3', 'table__87742.mp3' ), ('day_1.mp3', 'tay_1.mp3'),('day_2.mp3','tay_2.mp3'), 
                ('day__179392.mp3','tay__179392.mp3'), ('day__312237.mp3','tay__312237.mp3'), 
               ('dennis__117744.mp3','tennis__117744.mp3'), ('dennis__379332.mp3','tennis__379332.mp3'),
                ('dennis__404922.mp3','tennis__404922.mp3'),('dennis__515828.mp3','tennis__515828.mp3'),
               ('dog_1.mp3','tog_1.mp3'), ('dog_2.mp3','tog_2.mp3'),('dog__140203.mp3','tog__140203.mp3'),
                ('dog__82807.mp3','tog__82807.mp3'), ('game.mp3','kame.mp3'),('game__12639.mp3','kame__12639.mp3'),
                ('game__237071.mp3','kame__237071.mp3') ,('game__302107.mp3','kame__302107.mp3'),
                ('girl_1.mp3','kirl_1.mp3'), ('girl_2.mp3','kirl_2.mp3'),('girl__445999.mp3','kirl__445999.mp3'),
                ('girl__546475.mp3','kirl__546475.mp3'),('guyte__124442.mp3','kite__124442.mp3'), 
                ('guyte__289960.mp3','kite__289960.mp3'), ('guyte__478721.mp3','kite__478721.mp3'), 
                ('guyte__511647.mp3','kite__511647.mp3'), ('guyte__7511.mp3','kite__7511.mp3')]

# %%
# create a Dictionary of specific positioned phonemes (original & manipulated) and their feature vectors.
def dict_specific_phoneme_per_layer(layer):
    layer={}
    for idx in range(len(matching_mp3)):
        key = np.delete(both_mp3_pho[matching_mp3[idx][0]],
                        [i for i in range(len(both_mp3_pho[matching_mp3[idx][0]])) if i!=mp3_pho_idx[matching_mp3[idx][0]]])[0]
        if matching_mp3[idx][0] in manipulated_mp3:
            layer[key+str(idx)]= {'manipulated':{'phoneme':np.delete(both_mp3_pho[matching_mp3[idx][0]],
                                                                    [i for i in range(len(both_mp3_pho[matching_mp3[idx][0]])) if i!=mp3_pho_idx[matching_mp3[idx][0]]]),
                                                'feature':np.array([both_mp3_features[matching_mp3[idx][0]][mp3_pho_idx[matching_mp3[idx][0]]]])},
                                 'original':{'phoneme':np.delete(both_mp3_pho[matching_mp3[idx][1]],
                                                                 [i for i in range(len(both_mp3_pho[matching_mp3[idx][1]])) if i!=mp3_pho_idx[matching_mp3[idx][1]]]),
                                             'feature':np.array([both_mp3_features[matching_mp3[idx][1]][mp3_pho_idx[matching_mp3[idx][1]]]])}}
        else:
            layer[key+str(idx)]= {'original':{'phoneme':np.delete(both_mp3_pho[matching_mp3[idx][0]],
                                                                 [i for i in range(len(both_mp3_pho[matching_mp3[idx][0]])) if i!=mp3_pho_idx[matching_mp3[idx][0]]]),
                                             'feature':np.array([both_mp3_features[matching_mp3[idx][0]][mp3_pho_idx[matching_mp3[idx][0]]]])},
                                 'manipulated':{'phoneme':np.delete(both_mp3_pho[matching_mp3[idx][1]],
                                                                    [i for i in range(len(both_mp3_pho[matching_mp3[idx][1]])) if i!=mp3_pho_idx[matching_mp3[idx][1]]]),
                                                'feature':np.array([both_mp3_features[matching_mp3[idx][1]][mp3_pho_idx[matching_mp3[idx][1]]]])}}
    return layer

# %%
#final step 
#separate all the manipualted phonemes and their feature vectors, from the original ones. 

def list_separated(layer):
    original_ph = np.array([], dtype='<U2')
    manipulated_ph = np.array([], dtype='<U2')
    for pho in dict_specific_phoneme_per_layer(layer):
        original_ph = np.append(original_ph,dict_specific_phoneme_per_layer(layer)[pho]['original']['phoneme'])
        manipulated_ph = np.append(manipulated_ph,dict_specific_phoneme_per_layer(layer)[pho]['manipulated']['phoneme'])
    
    original_feat = np.vstack(tuple([dict_specific_phoneme_per_layer(layer)[pho]['original']['feature'] for pho in dict_specific_phoneme_per_layer(layer)]))
    manipulated_feat = np.vstack(tuple([dict_specific_phoneme_per_layer(layer)[pho]['manipulated']['feature'] for pho in dict_specific_phoneme_per_layer(layer)]))
    
    dictionary = {'original':(original_ph,original_feat), 'manipulated':(manipulated_ph,manipulated_feat)}
    
    return dictionary

# %%
# separate the different phonemes and their feature vectors (manipulated and original) from each other 

def letters_separate(layer):
    
    #original letters and their features 
    ori_feature_P = np.vstack(tuple([list_separated(layer)['original'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['original'][0]) if pho =='p']))
    ori_pho_P =np.array([], dtype='<U2')
    ori_pho_P = np.append(ori_pho_P, [pho for pho in list_separated(layer)['original'][0] if pho =='p'])
    
    ori_feature_B = np.vstack(tuple([list_separated(layer)['original'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['original'][0]) if pho =='b']))
    ori_pho_B =np.array([], dtype='<U2')
    ori_pho_B = np.append(ori_pho_B, [pho for pho in list_separated(layer)['original'][0] if pho =='b'])
    
    ori_feature_T = np.vstack(tuple([list_separated(layer)['original'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['original'][0]) if pho =='t']))
    ori_pho_T =np.array([], dtype='<U2')
    ori_pho_T = np.append(ori_pho_T, [pho for pho in list_separated(layer)['original'][0] if pho =='t'])
    
    ori_feature_K = np.vstack(tuple([list_separated(layer)['original'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['original'][0]) if pho =='k']))
    ori_pho_K =np.array([], dtype='<U2')
    ori_pho_K = np.append(ori_pho_K, [pho for pho in list_separated(layer)['original'][0] if pho =='k'])
    
    ori_feature_G = np.vstack(tuple([list_separated(layer)['original'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['original'][0]) if pho =='g']))
    ori_pho_G =np.array([], dtype='<U2')
    ori_pho_G = np.append(ori_pho_G, [pho for pho in list_separated(layer)['original'][0] if pho =='g'])
    
    ori_feature_D = np.vstack(tuple([list_separated(layer)['original'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['original'][0]) if pho =='d']))
    ori_pho_D =np.array([], dtype='<U2')
    ori_pho_D = np.append(ori_pho_D, [pho for pho in list_separated(layer)['original'][0] if pho =='d'])
    
    #manipulated letters and their features
    mani_feature_P = np.vstack(tuple([list_separated(layer)['manipulated'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['manipulated'][0]) if pho =='p']))
    mani_pho_P =np.array([], dtype='<U2')
    mani_pho_P = np.append(mani_pho_P, [pho for pho in list_separated(layer)['manipulated'][0] if pho =='p'])
    
    mani_feature_B = np.vstack(tuple([list_separated(layer)['manipulated'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['manipulated'][0]) if pho =='b']))
    mani_pho_B =np.array([], dtype='<U2')
    mani_pho_B = np.append(mani_pho_B, [pho for pho in list_separated(layer)['manipulated'][0] if pho =='b'])
    
    mani_feature_T = np.vstack(tuple([list_separated(layer)['manipulated'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['manipulated'][0]) if pho =='t']))
    mani_pho_T =np.array([], dtype='<U2')
    mani_pho_T = np.append(mani_pho_T, [pho for pho in list_separated(layer)['manipulated'][0] if pho =='t'])
    
    mani_feature_K = np.vstack(tuple([list_separated(layer)['manipulated'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['manipulated'][0]) if pho =='k']))
    mani_pho_K =np.array([], dtype='<U2')
    mani_pho_K = np.append(mani_pho_K, [pho for pho in list_separated(layer)['manipulated'][0] if pho =='k'])
    
    mani_feature_G = np.vstack(tuple([list_separated(layer)['manipulated'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['manipulated'][0]) if pho =='g']))
    mani_pho_G =np.array([], dtype='<U2')
    mani_pho_G = np.append(mani_pho_G, [pho for pho in list_separated(layer)['manipulated'][0] if pho =='g'])
    
    mani_feature_D = np.vstack(tuple([list_separated(layer)['manipulated'][1][idx] 
                                 for idx, pho in enumerate(list_separated(layer)['manipulated'][0]) if pho =='d']))
    mani_pho_D =np.array([], dtype='<U2')
    mani_pho_D = np.append(mani_pho_D, [pho for pho in list_separated(layer)['manipulated'][0] if pho =='d'])
    
    letter_dictio = {'p':{'original':(ori_pho_P, ori_feature_P), 'manipulated':(mani_pho_P, mani_feature_P)},
                    'b':{'original':(ori_pho_B, ori_feature_B), 'manipulated':(mani_pho_B, mani_feature_B)},
                    'd':{'original':(ori_pho_D, ori_feature_D), 'manipulated':(mani_pho_D, mani_feature_D)},
                    't':{'original':(ori_pho_T, ori_feature_T), 'manipulated':(mani_pho_T, mani_feature_T)},
                    'g':{'original':(ori_pho_G, ori_feature_G), 'manipulated':(mani_pho_G, mani_feature_G)},
                    'k':{'original':(ori_pho_K, ori_feature_K), 'manipulated':(mani_pho_K, mani_feature_K)}}
    
    
    return letter_dictio
